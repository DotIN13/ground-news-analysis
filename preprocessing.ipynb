# %%
import os
import json
import pandas as pd

# %%
interest = "israeli-palestinian-conflict"

# %%
# articles = []

# for file in os.listdir(f"data/{interest}/json"):
#     if file.endswith(".json"):
#         with open(f"data/{interest}/json/{file}", "r") as f:
#             data = json.load(f)
#             articles.append(data)

# df = pd.DataFrame(articles)

# %%
# df.isna().sum()

# %% [markdown]
# # Load data

# %%
stories = None

with open(f"data/sources_by_interest/story_ids_{interest}.json", "r", encoding="utf-8") as f:
    stories = json.load(f)

# %%
def extract_bias_data(data, sid, interest):
    """
    Extract only the variables useful for media bias analysis.
    
    Retained fields:
      - title: The article title.
      - description: The article description.
      - date: The publication date.
      - url: The article URL.
    
    From sourceInfo:
      - source_name: Media outlet name.
      - source_bias: The declared bias of the source.
      - source_factuality: Factuality rating.
      - source_originalBias: Original bias label.
      - source_owners: Comma-separated list of owner names.
      - source_biasRatings: Semicolon-separated bias ratings from different reviewers (format: ReviewerName:PoliticalBias).
      - source_lat & source_lon: Location coordinates.
      - source_place: Comma-separated list of place names (e.g., country).
    """
    result = {}
    result["interest_slug"] = interest
    result["story_id"] = sid
    # Article-level fields
    result["title"] = data.get("title")
    result["description"] = data.get("description")
    result["date"] = data.get("date")
    result["url"] = data.get("url")
    result["lang"] = data.get("lang")
    result["paywall"] = data.get("paywall")
    
    # Source-level fields
    source_info = data.get("sourceInfo", {})
    result["source_name"] = source_info.get("name")
    result["source_slug"] = source_info.get("slug")
    result["source_bias"] = source_info.get("bias")
    result["source_factuality"] = source_info.get("factuality")
    result["source_originalBias"] = source_info.get("originalBias")
    result["source_storyCount"] = source_info.get("storyCount")
    
    # Extract owners (if any)
    owners = source_info.get("owners", [])
    result["source_owners"] = ", ".join(owner.get("name", "") for owner in owners)
    
    # Extract bias ratings from different reviewers
    bias_ratings = source_info.get("biasRatings", [])
    ratings_list = []
    for br in bias_ratings:
        reviewer = br.get("reviewer", {})
        reviewer_name = reviewer.get("name", "")
        political_bias = br.get("politicalBias", "")
        ratings_list.append(f"{reviewer_name}:{political_bias}")
    result["source_biasRatings"] = "; ".join(ratings_list)
    
    # Include source location (if available)
    location = source_info.get("location") or {}
    result["source_lat"] = location.get("lat")
    result["source_lon"] = location.get("lon")
    
    # Include place names (e.g., country)
    places = source_info.get("place", [])
    result["source_place"] = ", ".join(p.get("name", "") for p in places)
    
    # Include article information
    ref_id = data.get("refId")
    if not ref_id:
        return result

    article_file = f"data/{interest}/json/{ref_id}.json"
    if not os.path.exists(article_file):
        return result

    article_data = None
    with open(article_file, "r") as f:
        article_data = json.load(f)
    
    result["article_title"] = article_data.get("title")
    result["article_description"] = article_data.get("description")
    result["article_image_url"] = article_data.get("image_url")
    result["article_text"] = article_data.get("maintext")
    result["article_date_publish"] = article_data.get("date_publish")
    result["article_authors"] = "; ".join(article_data.get("authors", []))
    
    return result

# %%
import csv

data = []

for sid, story in stories.items():
    if len(story["sources"]) < 2:
        continue
    
    for source in story["sources"]:
        article = extract_bias_data(source, sid, interest)
        data.append(article)

df = pd.DataFrame(data)
df.to_csv(f"data/{interest}_articles.csv", index=False, encoding="utf-8", quoting=csv.QUOTE_NONNUMERIC)

# %%
df
# Out:
#                        interest_slug                              story_id  \
# 0       israeli-palestinian-conflict  ad2c7886-e3d1-4630-bbde-d1965f491ef1
# 1       israeli-palestinian-conflict  ad2c7886-e3d1-4630-bbde-d1965f491ef1
# 2       israeli-palestinian-conflict  ad2c7886-e3d1-4630-bbde-d1965f491ef1
# 3       israeli-palestinian-conflict  ad2c7886-e3d1-4630-bbde-d1965f491ef1
# 4       israeli-palestinian-conflict  ad2c7886-e3d1-4630-bbde-d1965f491ef1
# ...                              ...                                   ...
# 118695  israeli-palestinian-conflict             rss_9636_1739016580753_13
# 118696  israeli-palestinian-conflict  931f3782-2de1-4d8f-9e76-c42922b76a97
# 118697  israeli-palestinian-conflict  931f3782-2de1-4d8f-9e76-c42922b76a97
# 118698  israeli-palestinian-conflict              rss_7287_1738455800744_9
# 118699  israeli-palestinian-conflict              rss_7287_1738455800744_9
#
#                                                     title  \
# 0       Gaza: Six babies have died from cold in two we...
# 1       Medics say 6 babies have died from the cold in...
# 2       Medics say 6 babies have died from the cold in...
# 3       At least 6 infants dead in Gaza due to cold we...
# 4       Medics say 6 babies have died from the cold in...
# ...                                                   ...
# 118695  From Sartre to Mélenchon, Michel Onfray traces...
# 118696  Those refusing to leave Gaza ‘probably Hamas’ ...
# 118697  Israeli envoy slams media, leaders for backing...
# 118698  Fourth non-bullying exchange of hostages and p...
# 118699  Israel-Hamas. Despite a new exchange of hostag...
#
#                                               description  \
# 0       Five newborns and a two-month-old have reporte...
# 1       Palestinian medics say at least six infants ha...
# 2       At least six infants have died from hypothermi...
# 3       At least six infants have died from cold-relat...
# 4       Palestinian medics say at least six infants ha...
# ...                                                   ...
# 118695  MAINTENANCE. Evidence in support, Michel Onfra...
# 118696  We spoke to Fleur Hassan-Nahoum, the Special E...
# 118697  New Delhi: Israeli Ambassador to India Reuven ...
# 118698  In contrast to Thursday's chaos and reprisals,...
# 118699  After days of uncertainty, the Israeli authori...
#
#                             date  \
# 0       2025-02-25T21:31:42.000Z
# 1       2025-02-25T15:36:46.000Z
# 2       2025-02-25T17:06:59.000Z
# 3       2025-02-25T22:00:34.000Z
# 4       2025-02-25T16:53:09.000Z
# ...                          ...
# 118695  2025-02-26T14:00:04.000Z
# 118696  2025-02-05T20:58:16.000Z
# 118697  2025-02-26T13:48:59.000Z
# 118698  2025-02-01T23:00:00.000Z
# 118699  2025-02-26T18:06:37.000Z
#
#                                                       url lang    paywall  \
# 0          https://www.bbc.com/news/articles/c62k676gk34o   en         no
# 1       https://www.independent.co.uk/news/gaza-israel...   en  sometimes
# 2       https://www.ctvnews.ca/world/israel-hamas-war/...   en         no
# 3       https://www.cbc.ca/news/world/infants-dead-hyp...   en         no
# 4       https://apnews.com/article/israel-palestinians...   en         no
# ...                                                   ...  ...        ...
# 118695  https://www.lejdd.fr/Societe/de-sartre-a-melen...   fr         no
# 118696  https://www.channel4.com/news/those-refusing-t...   en         no
# 118697  https://www.orissapost.com/israeli-envoy-slams...   en         no
# 118698  https://www.lavanguardia.com/internacional/202...   es         no
# 118699  https://www.courrierinternational.com/article/...   fr         no
#
#                    source_name             source_slug  ...  \
# 0                     BBC News         bbc-news_bf95f4  ...
# 1              The Independent  the-independent_ff73a6  ...
# 2                     CTV News                ctv-news  ...
# 3                     CBC News                cbc-news  ...
# 4        Associated Press News   associated-press-news  ...
# ...                        ...                     ...  ...
# 118695                lejdd.fr                 lejddfr  ...
# 118696               Channel 4               channel-4  ...
# 118697             Orissa POST             orissa-post  ...
# 118698           La Vanguardia           la-vanguardia  ...
# 118699  Courrier international  courrier-international  ...
#
#                                        source_biasRatings source_lat  \
# 0       Ad Fontes Media:center; All Sides:center; Medi...  52.449128
# 1       Ad Fontes Media:leanLeft; All Sides:leanLeft; ...  51.510428
# 2                            Media Bias/Fact Check:center  56.081144
# 3       Ad Fontes Media:center; All Sides:leanLeft; Me...  56.776486
# 4       Ad Fontes Media:center; All Sides:left; Media ...  37.300260
# ...                                                   ...        ...
# 118695                                                           NaN
# 118696  All Sides:leanLeft; Media Bias/Fact Check:lean...  51.490004
# 118697                                                           NaN
# 118698                                                     37.176733
# 118699                                                           NaN
#
#         source_lon                                     source_place  \
# 0        -1.798570                                   United Kingdom
# 1        -0.106444  London, Greater London, England, United Kingdom
# 2      -107.789090                                           Canada
# 3      -108.378064                                           Canada
# 4       -94.708464                                    United States
# ...            ...                                              ...
# 118695         NaN
# 118696   -0.137822  London, Greater London, England, United Kingdom
# 118697         NaN
# 118698   -3.596118                        Granada, Andalusia, Spain
# 118699         NaN
#
#                                             article_title  \
# 0       Six babies have died from cold in two weeks, m...
# 1       Six babies died from cold in Gaza over two wee...
# 2             6 babies died from cold in Gaza, medics say
# 3       Medical officials in Gaza sound the alarm afte...
# 4       Medics say 6 babies have died from the cold in...
# ...                                                   ...
# 118695  De Sartre à Mélenchon, Michel Onfray retrace l...
# 118696  Those refusing to leave Gaza ‘probably Hamas’ ...
# 118697                                                NaN
# 118698  Cuarto intercambio sin sobresaltos de rehenes ...
# 118699  Israël-Hamas. Malgré un nouvel échange d’otage...
#
#                                       article_description  \
# 0       Five newborns and a two-month-old have reporte...
# 1       Gaza health ministry records 15 deaths from hy...
# 2       At least six infants have died from hypothermi...
# 3       At least six infants have died from cold-relat...
# 4       Palestinian medics say at least six infants ha...
# ...                                                   ...
# 118695  ENTRETIEN. Preuves à l’appui, Michel Onfray an...
# 118696  We spoke to Fleur Hassan-Nahoum, the Special E...
# 118697                                                NaN
# 118698  El cese al fuego entre Israel y Hamas vivió po...
# 118699  Après des jours d’incertitudes, les autorités ...
#
#                                         article_image_url  \
# 0       https://ichef.bbci.co.uk/news/1024/branded_new...
# 1       https://static.independent.co.uk/2025/02/25/11...
# 2       https://www.ctvnews.ca/resizer/v2/TSNHSZMVGQV3...
# 3       https://i.cbc.ca/1.7467722.1740495952!/fileIma...
# 4       https://dims.apnews.com/dims4/default/9997738/...
# ...                                                   ...
# 118695  https://www.lejdd.fr/lmnr/var/jdd/public/media...
# 118696  https://fournews-assets-prod-s3-ew1-nmprod.s3....
# 118697                                                NaN
# 118698  https://www.lavanguardia.com/files/og_thumbnai...
# 118699  https://focus.courrierinternational.com/2025/0...
#
#                                              article_text  \
# 0       At least six babies have died in the past two ...
# 1       At least six infants have died from hypothermi...
# 2       The Shopping Trends team is independent of the...
# 3       WARNING: This story contains an image of an in...
# 4       DEIR AL-BALAH, Gaza Strip (AP) — At least six ...
# ...                                                   ...
# 118695  Vous faites justice de l’idée reçue selon laqu...
# 118696  We spoke to Fleur Hassan-Nahoum, the Special E...
# 118697                                                NaN
# 118698  El cese al fuego entre Israel y Hamas vivió po...
# 118699  “Le cessez-le-feu, bien que fragile, reste en ...
#
#        article_date_publish                                    article_authors
# 0       2025-02-25 21:31:42                                      David Gritten
# 1       2025-02-26 03:11:37                          Wafaa Shurafa; Samy Magdy
# 2       2025-02-25 20:00:38                               The Associated Press
# 3       2025-02-25 18:02:36                          Sara Jabakhanji; CBC News
# 4       2025-02-25 15:36:46  Wafaa Shurafa; Samy Magdy; apnews.com; samy-magdy
# ...                     ...                                                ...
# 118695  2025-02-26 00:00:00               Propos recueillis par; Éric Naulleau
# 118696  2025-02-05 00:00:00                 Krishnan Guru-Murthy; facebook.com
# 118697                  NaN                                                NaN
# 118698  2025-02-02 00:00:00                                 Janira Gómez Muñoz
# 118699  2025-02-14 00:00:00
#
# [118700 rows x 25 columns]
